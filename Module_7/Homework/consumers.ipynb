# %%
from kafka import KafkaConsumer

server = 'localhost:9092'
topic_name = 'green-trips'

# %%
from models import Trip, trip_deserializer
from dataclasses import asdict

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    group_id='rides-console',
    value_deserializer=trip_deserializer
)

# %%
records = []
for _ in consumer:
    records.append(asdict(_.value))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 records = []
# ----> 2 for _ in consumer:
#       3     records.append(asdict(_.value))
#
# File ~/de-zoomcamp/.venv/lib/python3.13/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File ~/de-zoomcamp/.venv/lib/python3.13/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File ~/de-zoomcamp/.venv/lib/python3.13/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File ~/de-zoomcamp/.venv/lib/python3.13/site-packages/kafka/consumer/group.py:757, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     754     log.debug('poll: do not have all fetch positions...')
#     755     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 757 self._client.poll(timeout_ms=poll_timeout_ms)
#     758 # after the long poll, we should check whether the group needs to rebalance
#     759 # prior to returning data so that the group can stabilize faster
#     760 if self._coordinator.need_rejoin():
#
# File ~/de-zoomcamp/.venv/lib/python3.13/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~/de-zoomcamp/.venv/lib/python3.13/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File ~/.local/share/uv/python/cpython-3.13.11-linux-x86_64-gnu/lib/python3.13/selectors.py:452, in EpollSelector.select(self, timeout)
#     450 ready = []
#     451 try:
# --> 452     fd_event_list = self._selector.poll(timeout, max_ev)
#     453 except InterruptedError:
#     454     return ready
#
# KeyboardInterrupt:

# %%
len(records)
# Out:
# 49416

# %%
import pandas as pd

# %%
df = pd.DataFrame(records)

# %%
df[df['trip_distance']>5]
# Out:
#       lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 3      2025-10-01 00:07:36   2025-10-01 00:32:14            95           170
# 5      2025-09-30 21:49:46   2025-10-01 21:18:42           129            37
# 7      2025-10-01 00:07:08   2025-10-01 00:21:46            95            70
# 8      2025-10-01 00:36:08   2025-10-01 00:54:59           181           137
# 11     2025-09-30 23:56:56   2025-10-01 00:10:51            95            80
# ...                    ...                   ...           ...           ...
# 49404  2025-10-31 23:11:25   2025-10-31 23:54:40           226            47
# 49405  2025-10-31 23:27:46   2025-10-31 23:59:23           179            47
# 49406  2025-10-31 23:20:00   2025-10-31 23:47:00            66           230
# 49411  2025-10-31 23:02:00   2025-11-01 00:28:33           241            61
# 49412  2025-10-31 23:51:34   2025-11-01 00:20:58            53           225
#
#        passenger_count  trip_distance  tip_amount  total_amount
# 3                    1          10.37       11.31         67.85
# 5                    1           7.13        9.42         47.12
# 7                    1           6.01        5.72         34.32
# 8                    1           6.45        6.98         41.88
# 11                   1           8.37        0.00         91.00
# ...                ...            ...         ...           ...
# 49404                0          11.49        0.00         39.11
# 49405                0           6.29        0.00         25.18
# 49406                0           6.74       10.39         62.32
# 49411                0          20.09        0.00         63.84
# 49412                0          10.11        0.00         34.76
#
# [8506 rows x 8 columns]
